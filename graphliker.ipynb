# %%
from copy import deepcopy
from graphliker import *
import os
circ = zx.generate.CNOT_HAD_PHASE_circuit(3, 80, p_had=0, p_t = 0.5, clifford = False)
if False:
    circ = Circuit(1)
    circ.add_gate(zx.gates.ZPhase(0, Fraction(1,4)))
    circ.add_gate(zx.gates.HAD(0))
    circ.add_gate(zx.gates.HAD(0))
    circ.add_gate(zx.gates.ZPhase(0, Fraction(1,4)))
    circ.add_gate(zx.gates.HAD(0))
    circ.add_gate(zx.gates.HAD(0))
    circ.add_gate(zx.gates.ZPhase(0, Fraction(1,4)))
zx.draw(circ, labels = True)
# Out:
# <div style="overflow:auto" id="graph-output-vezIfiAO"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...

# %%
## Note: There's a very rare bug that modifies semantics.
# Rare enough that it only seems to happen in cases I cannot feasibly verify_stepwise
g = to_graphlike(circ, quiet = False, dontdraw = False, verify_stepwise = False)
# Out:
# Frontier: [133, 135, 137]
# <div style="overflow:auto" id="graph-output-Sdg5987P"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...

# %%
g.normalize()
zx.draw(g)
zx.compare_tensors(g, circ.to_graph())
# Out:
# <div style="overflow:auto" id="graph-output-uzu1NB0l"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...

# %%
g.normalize()
zx.draw(g)
g2 = circ.to_graph()
zx.simplify.full_reduce(g2)
g2.normalize()
zx.draw(g2)
from copy import deepcopy
g3 = deepcopy(g)
zx.simplify.full_reduce(g3)
g3.normalize()
zx.draw(g3)
zx.compare_tensors(g2,g3)
# Out:
# <div style="overflow:auto" id="graph-output-i156QMsv"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...

# %%
return
gates = 7
circ = zx.generate.CNOT_HAD_PHASE_circuit(gates, 60, p_had=0.33, p_t = 0.33, clifford = True)

circ2 = deepcopy(circ)
circ2.add_gate(zx.gates.HAD(0))
circ2.add_gate(zx.gates.HAD(0))

quiet = True

if not quiet:
    print("regular")
g1 = to_graphlike(circ, quiet=quiet)
if not quiet:
    print("with added")
g2 = to_graphlike(circ2, quiet=quiet)
g5 = circ.to_graph();  zx.simplify.full_reduce(g5)
#g6 = circ2.to_graph(); zx.simplify.full_reduce(g6)
graphs = [g1, g2, g5]

for g in graphs:
    g.normalize()
    zx.draw(g)
    h_edges = [e for e in g.edges() if g.edge_type(e) == EdgeType.HADAMARD]
    internal_h_edges = [e for e in h_edges if g.type(e[0]) != VertexType.BOUNDARY != g.type(e[1])]
    print(f"H-edges: {len(h_edges)} ({len(internal_h_edges)} internal)")
    print("Equal?", zx.compare_tensors(graphs[0],g),"\nExtracted:")
    
    out = zx.extract_circuit(deepcopy(g))
    out = zx.optimize.basic_optimization(out.to_basic_gates(),do_swaps=False).to_basic_gates()
    zx.draw(out)
    print(out.stats())
# Out:
#   Cell In[5], line 1
#     return
#     ^
# SyntaxError: 'return' outside function

# %%
g4 = deepcopy(g5)
extract = [deepcopy(g4)]
zx.draw(g4, labels = True)
pivot_single_edge_raise_if_none(g4, (9, 3), "test", quiet=False)
extract.append(deepcopy(g4))
zx.draw(g4, labels = True)
lcomp_single_vertex_raise_if_none(g4, 45, "test", quiet=False)
extract.append(deepcopy(g4))
zx.draw(g4, labels = True)

if not zx.compare_tensors(g4,g5):
    raise ValueError("whoops")

for g in extract:
    out = zx.extract_circuit(deepcopy(g))
    out = zx.optimize.basic_optimization(out.to_basic_gates(),do_swaps=False).to_basic_gates()
    zx.draw(out)
